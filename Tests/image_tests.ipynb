# %%
# %cd ..
from map_provider import MapProvider
from IPython.display import display
# Out:
# d:\University\Bachelor\Code

# %% [markdown]
# #### Test loading image and cropping edge and random locations

# %%
city_map_dir = "City/NewCut/City_2017.jpg"
crop_size = 672
city_map = MapProvider(city_map_dir, crop_size)

# %%
random_x, random_y = city_map.generate_random_location()
display(city_map.get_cropped_image(random_x, random_y))
display(city_map.get_cropped_image(336, 336))
display(city_map.get_cropped_image(25807, 23658))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x21D31FC7FA0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x21D32049040>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x21D32044EB0>

# %%
particles = city_map.generate_random_locations(2000)
images = city_map.create_images_from_particles_threaded(particles)

for image in images[:1]:
  display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x21DBC22A130>

# %%
for image in images:
  image.close()
