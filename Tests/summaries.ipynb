# %%
# %cd ..
# Out:
# /workspaces/Code

# %%
import efficientnet.tfkeras as efn
import os
import tensorflow as tf
# from tensorflow.keras import applications

from keras.api._v2.keras import applications

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'

def enable_gpu_memory_growth():
    """
    Enables memory growth mode for GPUs.
    """
    gpus = tf.config.experimental.list_physical_devices('GPU')
    assert len(gpus) > 0, "No GPUs detected!"
            
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

enable_gpu_memory_growth()

# %%
model = efn.EfficientNetB2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# model = applications.ResNet50(include_top = False, weights = 'imagenet', input_shape=(224, 224, 3))
# model = applications.VGG16(include_top = False, weights = 'imagenet', input_shape=(224, 224, 3))
# model = applications.MobileNet(include_top = False, weights = 'imagenet', input_shape=(224, 224, 3), )
# model = applications.EfficientNetB1(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
model = applications.EfficientNetV2B0(include_top = False, weights = 'imagenet', input_shape=(224, 224, 3))

# %%
for index, layer in enumerate(model.layers):
    print('{}:'.format(index), layer.output_shape, layer.name)
# Out:
# 0: [(None, 224, 224, 3)] input_2
# 1: (None, 224, 224, 3) rescaling
# 2: (None, 224, 224, 3) normalization
# 3: (None, 112, 112, 32) stem_conv
# 4: (None, 112, 112, 32) stem_bn
# 5: (None, 112, 112, 32) stem_activation
# 6: (None, 112, 112, 16) block1a_project_conv
# 7: (None, 112, 112, 16) block1a_project_bn
# 8: (None, 112, 112, 16) block1a_project_activation
# 9: (None, 56, 56, 64) block2a_expand_conv
# 10: (None, 56, 56, 64) block2a_expand_bn
# 11: (None, 56, 56, 64) block2a_expand_activation
# 12: (None, 56, 56, 32) block2a_project_conv
# 13: (None, 56, 56, 32) block2a_project_bn
# 14: (None, 56, 56, 128) block2b_expand_conv
# 15: (None, 56, 56, 128) block2b_expand_bn
# 16: (None, 56, 56, 128) block2b_expand_activation
# 17: (None, 56, 56, 32) block2b_project_conv
# 18: (None, 56, 56, 32) block2b_project_bn
# 19: (None, 56, 56, 32) block2b_add
# 20: (None, 28, 28, 128) block3a_expand_conv
# 21: (None, 28, 28, 128) block3a_expand_bn
# ...

# %%
model.summary()
# Out:
# Model: "efficientnetv2-b0"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 224, 224, 3)  0           ['input_2[0][0]']
#
#  normalization (Normalization)  (None, 224, 224, 3)  0           ['rescaling[0][0]']
#
#  stem_conv (Conv2D)             (None, 112, 112, 32  864         ['normalization[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 112, 112, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 112, 112, 32  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 112, 112, 16  4608        ['stem_activation[0][0]']
# ...
